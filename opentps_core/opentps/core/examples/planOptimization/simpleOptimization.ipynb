# %% [markdown]
# # Simple IMPT plan optimization

# %%
import math
import os
import sys

import numpy as np
from matplotlib import pyplot as plt

from opentps.core.data.images import CTImage
from opentps.core.data.images import ROIMask
from opentps.core.data.plan import ObjectivesList
from opentps.core.data.plan import PlanDesign
from opentps.core.data import DVH
from opentps.core.data import Patient
from opentps.core.data.plan import FidObjective
from opentps.core.io import mcsquareIO
from opentps.core.io.scannerReader import readScanner
from opentps.core.io.serializedObjectIO import saveRTPlan, loadRTPlan
from opentps.core.processing.doseCalculation.doseCalculationConfig import DoseCalculationConfig
from opentps.core.processing.doseCalculation.mcsquareDoseCalculator import MCsquareDoseCalculator
from opentps.core.processing.imageProcessing.resampler3D import resampleImage3DOnImage3D, resampleImage3D
from opentps.core.processing.planOptimization.planOptimization import IMPTPlanOptimizer

# %% [markdown]
# ## CT calibration and BDL

# %%
ctCalibration = readScanner(DoseCalculationConfig().scannerFolder)
bdl = mcsquareIO.readBDL(DoseCalculationConfig().bdlFile)

# %% [markdown]
# ## Create synthetic CT and ROI

# %%
patient = Patient()
patient.name = 'Patient'

ctSize = 150

ct = CTImage()
ct.name = 'CT'
ct.patient = patient


huAir = -1024.
huWater = ctCalibration.convertRSP2HU(1.)
data = huAir * np.ones((ctSize, ctSize, ctSize))
data[:, 50:, :] = huWater
ct.imageArray = data

roi = ROIMask()
roi.patient = patient
roi.name = 'TV'
roi.color = (255, 0, 0) # red
data = np.zeros((ctSize, ctSize, ctSize)).astype(bool)
data[100:120, 100:120, 100:120] = True
roi.imageArray = data

# %% [markdown]
# ## Configure dose engine

# %%
mc2 = MCsquareDoseCalculator()
mc2.beamModel = bdl
mc2.nbPrimaries = 5e4
mc2.ctCalibration = ctCalibration

mc2._independentScoringGrid = True
scoringSpacing = [2, 2, 2]
mc2._scoringVoxelSpacing = scoringSpacing

# %% [markdown]
# ## Design plan

# %%
beamNames = ["Beam1"]
gantryAngles = [0.]
couchAngles = [0.]

planInit = PlanDesign()
planInit.ct = ct
planInit.targetMask = roi
planInit.gantryAngles = gantryAngles
planInit.beamNames = beamNames
planInit.couchAngles = couchAngles
planInit.calibration = ctCalibration
planInit.spotSpacing = 6.0
planInit.layerSpacing = 6.0
planInit.targetMargin = 0.0
planInit.scoringVoxelSpacing = [2, 2, 2]

plan = planInit.buildPlan()  # Spot placement
plan.PlanName = "NewPlan"

beamlets = mc2.computeBeamlets(ct, plan, roi=[roi])
plan.planDesign.beamlets = beamlets
doseImageRef = beamlets.toDoseImage()
# Out:
# 27/07/2023 04:37:25 PM - opentps.core.data.plan._planDesign - INFO - Building plan ...
# 27/07/2023 04:37:25 PM - opentps.core.processing.planOptimization.planInitializer - INFO - Target is dilated using a margin of 0.0 mm. This process might take some time.
# 27/07/2023 04:37:25 PM - opentps.core.processing.imageProcessing.roiMasksProcessing - INFO - Using SITK to dilate mask.
# 27/07/2023 04:37:28 PM - opentps.core.data.plan._planDesign - INFO - New plan created in 2.09409236907959 sec
# 27/07/2023 04:37:28 PM - opentps.core.data.plan._planDesign - INFO - Number of spots: 84
# 27/07/2023 04:37:28 PM - opentps.core.processing.doseCalculation.mcsquareDoseCalculator - INFO - Prepare MCsquare Beamlet calculation
# 27/07/2023 04:37:31 PM - opentps.core.io.mhdIO - INFO - Write MHD file: /home/eliot/openTPS_workspace/Simulations/MCsquare_simulation/CT.mhd
# 27/07/2023 04:37:31 PM - opentps.core.io.mcsquareIO - INFO - Write plan: /home/eliot/openTPS_workspace/Simulations/MCsquare_simulation/PlanPencil.txt
# 27/07/2023 04:37:32 PM - opentps.core.processing.doseCalculation.mcsquareDoseCalculator - INFO - Start MCsquare simulation
# MCsquare: 7: [: Linux: unexpected operator
#  Warning: Unknown tag "Optimization_Mode" in "config.txt"
#
#
# Initialization time: 0.598795 s
#
#
# Simulation of beamlet 84/84
# MC computation time: 2.801707 s
# Output computation time: 0.007629 s
#
# Simulation of beamlet 83/84
# MC computation time: 2.877325 s
# Output computation time: 0.006768 s
#
# Simulation of beamlet 76/84
# MC computation time: 2.908817 s
# Output computation time: 0.006957 s
#
# Simulation of beamlet 81/84
# MC computation time: 2.936700 s
# Output computation time: 0.006828 s
#
# Simulation of beamlet 73/84
# MC computation time: 2.936653 s
# Output computation time: 0.006867 s
#
# Simulation of beamlet 82/84
# MC computation time: 2.943382 s
# Output computation time: 0.006567 s
#
# Simulation of beamlet 79/84
# MC computation time: 2.952209 s
# Output computation time: 0.007394 s
#
# Simulation of beamlet 77/84
# MC computation time: 2.976436 s
# Output computation time: 0.006959 s
#
# Simulation of beamlet 80/84
# MC computation time: 2.979459 s
# Output computation time: 0.007112 s
#
# Simulation of beamlet 75/84
# MC computation time: 3.023465 s
# Output computation time: 0.007001 s
#
# Simulation of beamlet 78/84
# MC computation time: 3.030800 s
# Output computation time: 0.007156 s
#
# Simulation of beamlet 74/84
# MC computation time: 3.032178 s
# Output computation time: 0.006788 s
#
# Simulation of beamlet 70/84
# MC computation time: 3.043409 s
# Output computation time: 0.007311 s
#
# Simulation of beamlet 61/84
# MC computation time: 3.065376 s
# Output computation time: 0.006246 s
#
# Simulation of beamlet 72/84
# MC computation time: 3.071358 s
# Output computation time: 0.007113 s
#
# Simulation of beamlet 62/84
# MC computation time: 3.083380 s
# Output computation time: 0.007283 s
#
# Simulation of beamlet 71/84
# MC computation time: 3.105843 s
# Output computation time: 0.006682 s
#
# Simulation of beamlet 68/84
# MC computation time: 3.138373 s
# Output computation time: 0.006787 s
#
# Simulation of beamlet 60/84
# MC computation time: 3.158739 s
# Output computation time: 0.006797 s
#
# Simulation of beamlet 57/84
# MC computation time: 3.159296 s
# Output computation time: 0.006864 s
#
# Simulation of beamlet 58/84
# MC computation time: 3.168730 s
# Output computation time: 0.007008 s
#
# Simulation of beamlet 59/84
# MC computation time: 3.176338 s
# Output computation time: 0.006618 s
#
# Simulation of beamlet 67/84
# MC computation time: 3.200417 s
# Output computation time: 0.006319 s
#
# Simulation of beamlet 69/84
# MC computation time: 3.208238 s
# Output computation time: 0.006565 s
#
# Simulation of beamlet 63/84
# MC computation time: 3.218732 s
# Output computation time: 0.006827 s
#
# Simulation of beamlet 65/84
# MC computation time: 3.220825 s
# Output computation time: 0.006877 s
#
# Simulation of beamlet 66/84
# MC computation time: 3.250384 s
# Output computation time: 0.007436 s
#
# Simulation of beamlet 64/84
# MC computation time: 3.254527 s
# Output computation time: 0.006295 s
#
# Simulation of beamlet 43/84
# MC computation time: 3.414992 s
# Output computation time: 0.006205 s
#
# Simulation of beamlet 47/84
# MC computation time: 3.443203 s
# Output computation time: 0.006411 s
#
# Simulation of beamlet 55/84
# MC computation time: 3.455693 s
# Output computation time: 0.007028 s
#
# Simulation of beamlet 53/84
# MC computation time: 3.456507 s
# Output computation time: 0.006973 s
#
# Simulation of beamlet 51/84
# MC computation time: 3.457858 s
# Output computation time: 0.006659 s
#
# Simulation of beamlet 39/84
# MC computation time: 3.464962 s
# Output computation time: 0.005810 s
#
# Simulation of beamlet 49/84
# MC computation time: 3.506062 s
# Output computation time: 0.006076 s
#
# Simulation of beamlet 45/84
# MC computation time: 3.561503 s
# Output computation time: 0.010062 s
#
# Simulation of beamlet 41/84
# MC computation time: 3.621525 s
# Output computation time: 0.007013 s
#
# Simulation of beamlet 29/84
# MC computation time: 3.625025 s
# Output computation time: 0.007021 s
#
# Simulation of beamlet 33/84
# MC computation time: 3.647143 s
# Output computation time: 0.007375 s
#
# Simulation of beamlet 37/84
# MC computation time: 3.662185 s
# Output computation time: 0.007449 s
#
# Simulation of beamlet 31/84
# MC computation time: 3.673653 s
# Output computation time: 0.005848 s
#
# Simulation of beamlet 35/84
# MC computation time: 3.707940 s
# Output computation time: 0.006636 s
#
# Simulation of beamlet 25/84
# MC computation time: 3.759350 s
# Output computation time: 0.006448 s
#
# Simulation of beamlet 27/84
# MC computation time: 3.790483 s
# Output computation time: 0.006435 s
#
# Simulation of beamlet 21/84
# MC computation time: 3.805500 s
# Output computation time: 0.005954 s
#
# Simulation of beamlet 19/84
# MC computation time: 3.816331 s
# Output computation time: 0.006873 s
#
# Simulation of beamlet 11/84
# MC computation time: 3.840257 s
# Output computation time: 0.004165 s
#
# Simulation of beamlet 17/84
# MC computation time: 3.848887 s
# Output computation time: 0.006068 s
#
# Simulation of beamlet 23/84
# MC computation time: 3.863574 s
# Output computation time: 0.006584 s
#
# Simulation of beamlet 15/84
# MC computation time: 3.882936 s
# Output computation time: 0.005646 s
#
# Simulation of beamlet 7/84
# MC computation time: 3.982203 s
# Output computation time: 0.005793 s
#
# Simulation of beamlet 13/84
# MC computation time: 3.998517 s
# Output computation time: 0.006132 s
#
# Simulation of beamlet 5/84
# MC computation time: 4.006878 s
# Output computation time: 0.004087 s
#
# Simulation of beamlet 1/84
# MC computation time: 4.015948 s
# Output computation time: 0.006256 s
#
# Simulation of beamlet 9/84
# MC computation time: 4.028315 s
# Output computation time: 0.005997 s
#
# Simulation of beamlet 3/84
# MC computation time: 4.075450 s
# Output computation time: 0.003804 s
#
# Simulation of beamlet 44/84
# MC computation time: 2.162097 s
# Output computation time: 0.003082 s
#
# Simulation of beamlet 36/84
# MC computation time: 2.266743 s
# Output computation time: 0.003320 s
#
# Simulation of beamlet 30/84
# MC computation time: 2.342163 s
# Output computation time: 0.003273 s
#
# Simulation of beamlet 46/84
# MC computation time: 2.232214 s
# Output computation time: 0.003301 s
#
# Simulation of beamlet 50/84
# MC computation time: 2.251413 s
# Output computation time: 0.003238 s
#
# Simulation of beamlet 40/84
# MC computation time: 2.325612 s
# Output computation time: 0.002968 s
#
# Simulation of beamlet 48/84
# MC computation time: 2.343284 s
# Output computation time: 0.003219 s
#
# Simulation of beamlet 52/84
# MC computation time: 2.332851 s
# Output computation time: 0.003229 s
#
# Simulation of beamlet 42/84
# MC computation time: 2.408005 s
# Output computation time: 0.002931 s
#
# Simulation of beamlet 34/84
# MC computation time: 2.474246 s
# Output computation time: 0.003184 s
#
# Simulation of beamlet 20/84
# MC computation time: 2.576745 s
# Output computation time: 0.003259 s
#
# Simulation of beamlet 14/84
# MC computation time: 2.667974 s
# Output computation time: 0.003221 s
#
# Simulation of beamlet 56/84
# MC computation time: 2.367863 s
# Output computation time: 0.003156 s
#
# Simulation of beamlet 38/84
# MC computation time: 2.471685 s
# Output computation time: 0.002936 s
#
# Simulation of beamlet 32/84
# MC computation time: 2.568213 s
# Output computation time: 0.003245 s
#
# Simulation of beamlet 10/84
# MC computation time: 2.716582 s
# Output computation time: 0.003221 s
#
# Simulation of beamlet 26/84
# MC computation time: 2.614341 s
# Output computation time: 0.003180 s
#
# Simulation of beamlet 4/84
# MC computation time: 2.788230 s
# Output computation time: 0.003274 s
#
# Simulation of beamlet 16/84
# MC computation time: 2.760506 s
# Output computation time: 0.003267 s
#
# Simulation of beamlet 28/84
# MC computation time: 2.682675 s
# Output computation time: 0.002971 s
#
# Simulation of beamlet 2/84
# MC computation time: 2.949275 s
# Output computation time: 0.003264 s
#
# Simulation of beamlet 54/84
# MC computation time: 2.520282 s
# Output computation time: 0.003147 s
#
# Simulation of beamlet 22/84
# MC computation time: 2.770850 s
# Output computation time: 0.003156 s
#
# Simulation of beamlet 18/84
# MC computation time: 2.853543 s
# Output computation time: 0.003199 s
#
# Simulation of beamlet 8/84
# MC computation time: 2.905053 s
# Output computation time: 0.003183 s
#
# Simulation of beamlet 12/84
# MC computation time: 2.900541 s
# Output computation time: 0.003184 s
#
# Simulation of beamlet 24/84
# MC computation time: 2.821652 s
# Output computation time: 0.003210 s
#
# Simulation of beamlet 6/84
# MC computation time: 3.001167 s
# Output computation time: 0.003246 s
# Total computation time: 6.680475 s
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Read sparse beamlets: /home/eliot/openTPS_workspace/Simulations/MCsquare_simulation/Outputs/Sparse_Dose.txt
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Read binary file: /home/eliot/openTPS_workspace/Simulations/MCsquare_simulation/Outputs/Sparse_Dose.txt
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Beamlets are computed on ['TV']
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 0 : BeamID=1 LayerID=1 Position=(-9.0;-5.196152210235596) NonZeroVoxels=22470
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 1 : BeamID=1 LayerID=1 Position=(-9.0;5.196152210235596) NonZeroVoxels=22751
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 2 : BeamID=1 LayerID=1 Position=(-3.0;-5.196152210235596) NonZeroVoxels=22461
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 3 : BeamID=1 LayerID=1 Position=(-6.0;0.0) NonZeroVoxels=22648
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 4 : BeamID=1 LayerID=1 Position=(-3.0;5.196152210235596) NonZeroVoxels=22265
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 5 : BeamID=1 LayerID=1 Position=(-6.0;10.392305374145508) NonZeroVoxels=22203
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 6 : BeamID=1 LayerID=1 Position=(3.0;-5.196152210235596) NonZeroVoxels=21468
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 7 : BeamID=1 LayerID=1 Position=(0.0;0.0) NonZeroVoxels=21892
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 8 : BeamID=1 LayerID=1 Position=(3.0;5.196152210235596) NonZeroVoxels=21824
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 9 : BeamID=1 LayerID=1 Position=(0.0;10.392305374145508) NonZeroVoxels=21664
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 10 : BeamID=1 LayerID=1 Position=(9.0;-5.196152210235596) NonZeroVoxels=21948
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 11 : BeamID=1 LayerID=1 Position=(6.0;0.0) NonZeroVoxels=21720
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 12 : BeamID=1 LayerID=1 Position=(9.0;5.196152210235596) NonZeroVoxels=21563
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 13 : BeamID=1 LayerID=1 Position=(6.0;10.392305374145508) NonZeroVoxels=21779
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 14 : BeamID=1 LayerID=2 Position=(-9.0;-5.196152210235596) NonZeroVoxels=21250
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 15 : BeamID=1 LayerID=2 Position=(-9.0;5.196152210235596) NonZeroVoxels=21439
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 16 : BeamID=1 LayerID=2 Position=(-3.0;-5.196152210235596) NonZeroVoxels=21050
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 17 : BeamID=1 LayerID=2 Position=(-6.0;0.0) NonZeroVoxels=21341
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 18 : BeamID=1 LayerID=2 Position=(-3.0;5.196152210235596) NonZeroVoxels=21066
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 19 : BeamID=1 LayerID=2 Position=(-6.0;10.392305374145508) NonZeroVoxels=20942
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 20 : BeamID=1 LayerID=2 Position=(3.0;-5.196152210235596) NonZeroVoxels=20860
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 21 : BeamID=1 LayerID=2 Position=(0.0;0.0) NonZeroVoxels=20651
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 22 : BeamID=1 LayerID=2 Position=(3.0;5.196152210235596) NonZeroVoxels=20529
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 23 : BeamID=1 LayerID=2 Position=(0.0;10.392305374145508) NonZeroVoxels=20967
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 24 : BeamID=1 LayerID=2 Position=(9.0;-5.196152210235596) NonZeroVoxels=20594
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 25 : BeamID=1 LayerID=2 Position=(6.0;0.0) NonZeroVoxels=20490
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 26 : BeamID=1 LayerID=2 Position=(9.0;5.196152210235596) NonZeroVoxels=20890
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 27 : BeamID=1 LayerID=2 Position=(6.0;10.392305374145508) NonZeroVoxels=20534
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 28 : BeamID=1 LayerID=3 Position=(-9.0;-5.196152210235596) NonZeroVoxels=20288
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 29 : BeamID=1 LayerID=3 Position=(-9.0;5.196152210235596) NonZeroVoxels=20129
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 30 : BeamID=1 LayerID=3 Position=(-3.0;-5.196152210235596) NonZeroVoxels=20389
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 31 : BeamID=1 LayerID=3 Position=(-6.0;0.0) NonZeroVoxels=20134
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 32 : BeamID=1 LayerID=3 Position=(-3.0;5.196152210235596) NonZeroVoxels=20024
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 33 : BeamID=1 LayerID=3 Position=(-6.0;10.392305374145508) NonZeroVoxels=19665
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 34 : BeamID=1 LayerID=3 Position=(3.0;-5.196152210235596) NonZeroVoxels=20163
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 35 : BeamID=1 LayerID=3 Position=(0.0;0.0) NonZeroVoxels=20105
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 36 : BeamID=1 LayerID=3 Position=(3.0;5.196152210235596) NonZeroVoxels=19317
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 37 : BeamID=1 LayerID=3 Position=(0.0;10.392305374145508) NonZeroVoxels=19880
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 38 : BeamID=1 LayerID=3 Position=(9.0;-5.196152210235596) NonZeroVoxels=19562
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 39 : BeamID=1 LayerID=3 Position=(6.0;0.0) NonZeroVoxels=19662
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 40 : BeamID=1 LayerID=3 Position=(9.0;5.196152210235596) NonZeroVoxels=19376
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 41 : BeamID=1 LayerID=3 Position=(6.0;10.392305374145508) NonZeroVoxels=19266
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 42 : BeamID=1 LayerID=4 Position=(-9.0;-5.196152210235596) NonZeroVoxels=19421
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 43 : BeamID=1 LayerID=4 Position=(-9.0;5.196152210235596) NonZeroVoxels=19381
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 44 : BeamID=1 LayerID=4 Position=(-3.0;-5.196152210235596) NonZeroVoxels=19521
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 45 : BeamID=1 LayerID=4 Position=(-6.0;0.0) NonZeroVoxels=19384
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 46 : BeamID=1 LayerID=4 Position=(-3.0;5.196152210235596) NonZeroVoxels=19105
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 47 : BeamID=1 LayerID=4 Position=(-6.0;10.392305374145508) NonZeroVoxels=18666
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 48 : BeamID=1 LayerID=4 Position=(3.0;-5.196152210235596) NonZeroVoxels=18841
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 49 : BeamID=1 LayerID=4 Position=(0.0;0.0) NonZeroVoxels=18995
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 50 : BeamID=1 LayerID=4 Position=(3.0;5.196152210235596) NonZeroVoxels=18909
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 51 : BeamID=1 LayerID=4 Position=(0.0;10.392305374145508) NonZeroVoxels=19104
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 52 : BeamID=1 LayerID=4 Position=(9.0;-5.196152210235596) NonZeroVoxels=18538
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 53 : BeamID=1 LayerID=4 Position=(6.0;0.0) NonZeroVoxels=18226
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 54 : BeamID=1 LayerID=4 Position=(9.0;5.196152210235596) NonZeroVoxels=18612
# 27/07/2023 04:37:39 PM - opentps.core.io.mcsquareIO - INFO - Spot 55 : BeamID=1 LayerID=4 Position=(6.0;10.392305374145508) NonZeroVoxels=18296
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 56 : BeamID=1 LayerID=5 Position=(-9.0;-5.196152210235596) NonZeroVoxels=18326
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 57 : BeamID=1 LayerID=5 Position=(-9.0;5.196152210235596) NonZeroVoxels=18208
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 58 : BeamID=1 LayerID=5 Position=(-3.0;-5.196152210235596) NonZeroVoxels=17985
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 59 : BeamID=1 LayerID=5 Position=(-6.0;0.0) NonZeroVoxels=18487
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 60 : BeamID=1 LayerID=5 Position=(-3.0;5.196152210235596) NonZeroVoxels=17951
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 61 : BeamID=1 LayerID=5 Position=(-6.0;10.392305374145508) NonZeroVoxels=18089
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 62 : BeamID=1 LayerID=5 Position=(3.0;-5.196152210235596) NonZeroVoxels=18438
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 63 : BeamID=1 LayerID=5 Position=(0.0;0.0) NonZeroVoxels=18154
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 64 : BeamID=1 LayerID=5 Position=(3.0;5.196152210235596) NonZeroVoxels=17650
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 65 : BeamID=1 LayerID=5 Position=(0.0;10.392305374145508) NonZeroVoxels=17490
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 66 : BeamID=1 LayerID=5 Position=(9.0;-5.196152210235596) NonZeroVoxels=17578
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 67 : BeamID=1 LayerID=5 Position=(6.0;0.0) NonZeroVoxels=17679
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 68 : BeamID=1 LayerID=5 Position=(9.0;5.196152210235596) NonZeroVoxels=17546
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 69 : BeamID=1 LayerID=5 Position=(6.0;10.392305374145508) NonZeroVoxels=17573
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 70 : BeamID=1 LayerID=6 Position=(-9.0;-5.196152210235596) NonZeroVoxels=17714
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 71 : BeamID=1 LayerID=6 Position=(-9.0;5.196152210235596) NonZeroVoxels=17411
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 72 : BeamID=1 LayerID=6 Position=(-3.0;-5.196152210235596) NonZeroVoxels=17441
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 73 : BeamID=1 LayerID=6 Position=(-6.0;0.0) NonZeroVoxels=17477
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 74 : BeamID=1 LayerID=6 Position=(-3.0;5.196152210235596) NonZeroVoxels=17146
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 75 : BeamID=1 LayerID=6 Position=(-6.0;10.392305374145508) NonZeroVoxels=17207
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 76 : BeamID=1 LayerID=6 Position=(3.0;-5.196152210235596) NonZeroVoxels=17291
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 77 : BeamID=1 LayerID=6 Position=(0.0;0.0) NonZeroVoxels=17159
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 78 : BeamID=1 LayerID=6 Position=(3.0;5.196152210235596) NonZeroVoxels=16846
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 79 : BeamID=1 LayerID=6 Position=(0.0;10.392305374145508) NonZeroVoxels=17279
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 80 : BeamID=1 LayerID=6 Position=(9.0;-5.196152210235596) NonZeroVoxels=17076
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 81 : BeamID=1 LayerID=6 Position=(6.0;0.0) NonZeroVoxels=16966
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 82 : BeamID=1 LayerID=6 Position=(9.0;5.196152210235596) NonZeroVoxels=16742
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Spot 83 : BeamID=1 LayerID=6 Position=(6.0;10.392305374145508) NonZeroVoxels=16806
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Beamlets imported in 1.177501916885376 sec
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Beamlets loaded
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Matrix size: (421875, 84)
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Non-zero values: 43244
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - data format: float32
# 27/07/2023 04:37:40 PM - opentps.core.io.mcsquareIO - INFO - Memory usage: 0.0003225095570087433 GB

# %% [markdown]
# ## Objectives

# %%
plan.planDesign.objectives = ObjectivesList()
plan.planDesign.objectives.setTarget(roi.name, 20.0)

plan.planDesign.objectives.fidObjList = []
plan.planDesign.objectives.addFidObjective(roi, FidObjective.Metrics.DMAX, 20.0, 1.0)
plan.planDesign.objectives.addFidObjective(roi, FidObjective.Metrics.DMIN, 20.5, 1.0)

# %% [markdown]
# ## Optimize plan

# %%
solver = IMPTPlanOptimizer(method='Scipy-LBFGS', plan=plan, maxit=50)
w, doseImage, ps = solver.optimize()

plan.spotMUs = np.square(w).astype(np.float32)
# Out:
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.planOptimization - INFO - Prepare optimization ...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           84     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.69799D+02    |proj g|=  3.77717D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 1 of Scipy-L-BFGS-B
#
# At iterate    1    f=  5.15872D+01    |proj g|=  2.16194D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.158724e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 2 of Scipy-L-BFGS-B
#
# At iterate    2    f=  3.98964D+01    |proj g|=  3.81632D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 3.989635e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 3 of Scipy-L-BFGS-B
#
# At iterate    3    f=  3.07750D+01    |proj g|=  3.68890D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 3.077499e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 4 of Scipy-L-BFGS-B
#
# At iterate    4    f=  2.11911D+01    |proj g|=  1.94978D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 2.119108e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 5 of Scipy-L-BFGS-B
#
# At iterate    5    f=  1.86233D+01    |proj g|=  1.31631D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.862325e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 6 of Scipy-L-BFGS-B
#
# At iterate    6    f=  1.66554D+01    |proj g|=  9.10260D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.665537e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 7 of Scipy-L-BFGS-B
#
# At iterate    7    f=  1.50314D+01    |proj g|=  8.84171D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.503139e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 8 of Scipy-L-BFGS-B
#
# At iterate    8    f=  1.25478D+01    |proj g|=  1.07784D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.254785e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 9 of Scipy-L-BFGS-B
#
# At iterate    9    f=  1.01569D+01    |proj g|=  6.15658D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.015689e+01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 10 of Scipy-L-BFGS-B
#
# At iterate   10    f=  9.22909D+00    |proj g|=  1.21721D+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 9.229092e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 11 of Scipy-L-BFGS-B
#
# At iterate   11    f=  8.48606D+00    |proj g|=  4.48535D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 8.486061e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 12 of Scipy-L-BFGS-B
#
# At iterate   12    f=  8.17790D+00    |proj g|=  2.37194D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 8.177903e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 13 of Scipy-L-BFGS-B
#
# At iterate   13    f=  8.00031D+00    |proj g|=  1.67184D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 8.000313e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 14 of Scipy-L-BFGS-B
#
# At iterate   14    f=  7.79949D+00    |proj g|=  2.20444D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.799489e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 15 of Scipy-L-BFGS-B
#
# At iterate   15    f=  7.62674D+00    |proj g|=  1.32842D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.626740e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 16 of Scipy-L-BFGS-B
#
# At iterate   16    f=  7.45553D+00    |proj g|=  9.52626D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.455525e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 17 of Scipy-L-BFGS-B
#
# At iterate   17    f=  7.37908D+00    |proj g|=  7.78151D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.379077e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 18 of Scipy-L-BFGS-B
#
# At iterate   18    f=  7.36533D+00    |proj g|=  7.78075D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.365328e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 19 of Scipy-L-BFGS-B
#
# At iterate   19    f=  7.35725D+00    |proj g|=  9.14232D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.357250e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 20 of Scipy-L-BFGS-B
#
# At iterate   20    f=  7.34965D+00    |proj g|=  2.23221D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.349645e+00
#  This problem is unconstrained.
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 21 of Scipy-L-BFGS-B
#
# At iterate   21    f=  7.34621D+00    |proj g|=  2.17151D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.346209e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 22 of Scipy-L-BFGS-B
#
# At iterate   22    f=  7.34110D+00    |proj g|=  3.21667D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.341099e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 23 of Scipy-L-BFGS-B
#
# At iterate   23    f=  7.33356D+00    |proj g|=  4.47038D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.333561e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 24 of Scipy-L-BFGS-B
#
# At iterate   24    f=  7.32837D+00    |proj g|=  4.40382D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.328366e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 25 of Scipy-L-BFGS-B
#
# At iterate   25    f=  7.31949D+00    |proj g|=  2.32881D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.319493e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 26 of Scipy-L-BFGS-B
#
# At iterate   26    f=  7.31334D+00    |proj g|=  2.41964D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.313336e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 27 of Scipy-L-BFGS-B
#
# At iterate   27    f=  7.30714D+00    |proj g|=  2.46340D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.307141e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 28 of Scipy-L-BFGS-B
#
# At iterate   28    f=  7.30141D+00    |proj g|=  4.45350D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.301407e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 29 of Scipy-L-BFGS-B
#
# At iterate   29    f=  7.29586D+00    |proj g|=  4.29519D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.295862e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 30 of Scipy-L-BFGS-B
#
# At iterate   30    f=  7.29220D+00    |proj g|=  4.93222D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.292200e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 31 of Scipy-L-BFGS-B
#
# At iterate   31    f=  7.28835D+00    |proj g|=  3.24498D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.288354e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 32 of Scipy-L-BFGS-B
#
# At iterate   32    f=  7.27911D+00    |proj g|=  3.46152D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.279112e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 33 of Scipy-L-BFGS-B
#
# At iterate   33    f=  7.26723D+00    |proj g|=  6.36600D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.267226e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 34 of Scipy-L-BFGS-B
#
# At iterate   34    f=  7.24641D+00    |proj g|=  1.07850D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.246414e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 35 of Scipy-L-BFGS-B
#
# At iterate   35    f=  7.22048D+00    |proj g|=  1.96671D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.220476e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 36 of Scipy-L-BFGS-B
#
# At iterate   36    f=  7.17358D+00    |proj g|=  1.72861D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.173579e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 37 of Scipy-L-BFGS-B
#
# At iterate   37    f=  7.13040D+00    |proj g|=  6.67133D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.130400e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 38 of Scipy-L-BFGS-B
#
# At iterate   38    f=  7.09807D+00    |proj g|=  5.14742D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.098072e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 39 of Scipy-L-BFGS-B
#
# At iterate   39    f=  7.07985D+00    |proj g|=  1.57011D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.079852e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 40 of Scipy-L-BFGS-B
#
# At iterate   40    f=  7.05379D+00    |proj g|=  7.64865D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.053795e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 41 of Scipy-L-BFGS-B
#
# At iterate   41    f=  7.04248D+00    |proj g|=  4.09745D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.042485e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 42 of Scipy-L-BFGS-B
#
# At iterate   42    f=  7.02988D+00    |proj g|=  2.95606D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.029881e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 43 of Scipy-L-BFGS-B
#
# At iterate   43    f=  7.02596D+00    |proj g|=  1.74495D-01
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.025961e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 44 of Scipy-L-BFGS-B
#
# At iterate   44    f=  7.01376D+00    |proj g|=  4.98281D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.013759e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 45 of Scipy-L-BFGS-B
#
# At iterate   45    f=  7.00721D+00    |proj g|=  2.54138D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.007209e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 46 of Scipy-L-BFGS-B
#
# At iterate   46    f=  7.00213D+00    |proj g|=  3.99134D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.002131e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 47 of Scipy-L-BFGS-B
#
# At iterate   47    f=  6.99275D+00    |proj g|=  3.01220D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.992751e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 48 of Scipy-L-BFGS-B
#
# At iterate   48    f=  6.98957D+00    |proj g|=  5.35276D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.989570e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 49 of Scipy-L-BFGS-B
#
# At iterate   49    f=  6.98662D+00    |proj g|=  1.67197D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.986623e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 50 of Scipy-L-BFGS-B
#
# At iterate   50    f=  6.98536D+00    |proj g|=  1.39480D-02
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.985364e+00
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.planOptimization - INFO -  ScipyOpt terminated in 50 Iter, x = [9.924061131357135, 5.4348248702393285, 4.141406978027756, -0.0012785868635530112, -0.9451139390057667, 9.308092071695086, 9.014050843496248, 0.003126204723851939, 3.784118353914499, 0.02777145443680313, 7.008078277980084, 0.009316459198704203, 5.293053908420144, 8.731253846955179, 5.108329795757399, 1.8949075819770052, 2.8974592679001967, -0.013749587920181045, -0.16734849222268655, 5.190742560367642, 1.82730143037088, -0.06328376530038468, 0.1606098301671925, 0.3979146136040047, 5.444086823788423, 0.0073341356461576225, 0.35768444042249264, 5.329310107359409, 3.061140793603773, 3.584363010839823, 4.4581986801668, -0.036868466082812676, -0.2646315042452709, 3.675560073423788, 0.4384761434144785, 0.04082427678608978, 0.39597266642648893, -0.20798981533400532, 5.064455658852824, 0.009668106274353161, 0.7573459348128241, 5.058077868738755, 4.102453594396822, 2.3162287815354894, -0.6147062787055201, -0.016253948640365744, -0.410638247574988, 3.3449610665234095, 3.767207847595911, 0.001644802338377804, 0.9471737789101967, 1.0203676658693588, 2.6010435938695737, 0.044707184238829134, 0.356914831876008, 4.087832674712379, 4.3470976384895845, 3.7107053482124237, 6.65465696927194, 5.135630101767834, 5.512031986712108, 2.7578645643999438, 5.8479716643450095, 6.194612614549896, 5.220305388994555, 3.2809537942590143, 3.259371700004945, 4.816766882029348, 3.1509838107393895, 2.5271473920028824, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265, 0.8899253606796265], f(x) = [369.799072265625, 51.587239265441895, 39.896352767944336, 30.774991035461426, 21.191077709197998, 18.623250007629395, 16.655366897583008, 15.031388282775879, 12.547849178314209, 10.15689468383789, 9.229092121124268, 8.486060857772827, 8.177902936935425, 8.000312805175781, 7.7994890213012695, 7.626739978790283, 7.455525159835815, 7.379076719284058, 7.365328073501587, 7.357250452041626, 7.349645137786865, 7.346208810806274, 7.3410985469818115, 7.333561420440674, 7.3283655643463135, 7.319493055343628, 7.313336133956909, 7.307140588760376, 7.301407337188721, 7.295861721038818, 7.2921998500823975, 7.28835391998291, 7.279112339019775, 7.267225742340088, 7.246413946151733, 7.220476150512695, 7.173578977584839, 7.130399703979492, 7.098072290420532, 7.079852104187012, 7.053794860839844, 7.042484998703003, 7.029881000518799, 7.02596116065979, 7.013758659362793, 7.007208585739136, 7.002130508422852, 6.992750644683838, 6.989570379257202, 6.986623287200928, 6.9853644371032715], time elapsed 0.48886680603027344, time per iter 0.00977733612060547
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    84     50     58      1     0     0   1.395D-02   6.985D+00
#   F =   6.9853644371032715
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.planOptimization - INFO - Total dose calculation ...
# 27/07/2023 05:25:45 PM - opentps.core.processing.planOptimization.planOptimization - INFO - Optimization done.

# %% [markdown]
# ## Final dose computation

# %%
mc2.nbPrimaries = 1e7
doseImage = mc2.computeDose(ct, plan)
# Out:
# 27/07/2023 05:27:22 PM - opentps.core.processing.doseCalculation.mcsquareDoseCalculator - INFO - Prepare MCsquare Dose calculation
# 27/07/2023 05:27:22 PM - opentps.core.io.mhdIO - INFO - Write MHD file: /home/eliot/openTPS_workspace/Simulations/MCsquare_simulation/CT.mhd
# 27/07/2023 05:27:22 PM - opentps.core.io.mcsquareIO - INFO - Write plan: /home/eliot/openTPS_workspace/Simulations/MCsquare_simulation/PlanPencil.txt
# 27/07/2023 05:27:23 PM - opentps.core.processing.doseCalculation.mcsquareDoseCalculator - INFO - Start MCsquare simulation
# MCsquare: 7: [: Linux: unexpected operator
#  Warning: Unknown tag "Optimization_Mode" in "config.txt"
#
#
# Initialization time: 0.639518 s
#
#
# Simulation started (2023-07-27 17:27:23)
#  10.0 %
#  20.0 %
#  30.0 %
#  40.0 %
#  50.0 % (stat uncertainty: 0.61 %)
#  60.0 % (stat uncertainty: 0.59 %)
#  70.0 % (stat uncertainty: 0.55 %)
#  80.0 % (stat uncertainty: 0.52 %)
#  90.0 % (stat uncertainty: 0.49 %)
#  100.0 % (stat uncertainty: 0.47 %)
#
# Nbr primaries simulated: 10000000 (98511 generated outside the geometry)
# MC computation time: 14.883702 s
# Output computation time: 0.002013 s
#
# Total computation time: 15.525250 s

# %% [markdown]
# ## Plots

# %%
 # Compute DVH on resampled contour
roiResampled = resampleImage3D(roi, origin=ct.origin, gridSize=scoringGridSize, spacing=scoringSpacing)
target_DVH = DVH(roiResampled, doseImage)
print('D95 = ' + str(target_DVH.D95) + ' Gy')
print('D5 = ' + str(target_DVH.D5) + ' Gy')
print('D5 - D95 =  {} Gy'.format(target_DVH.D5 - target_DVH.D95))

# center of mass
roi = resampleImage3DOnImage3D(roi, ct)
COM_coord = roi.centerOfMass
COM_index = roi.getVoxelIndexFromPosition(COM_coord)
Z_coord = COM_index[2]

img_ct = ct.imageArray[:, :, Z_coord].transpose(1, 0)
contourTargetMask = roi.getBinaryContourMask()
img_mask = contourTargetMask.imageArray[:, :, Z_coord].transpose(1, 0)
img_dose = resampleImage3DOnImage3D(doseImage, ct)
img_dose = img_dose.imageArray[:, :, Z_coord].transpose(1, 0)

# Display dose
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
#ax[0].axes.get_xaxis().set_visible(False)
#ax[0].axes.get_yaxis().set_visible(False)
ax[0].imshow(img_ct, cmap='gray')
ax[0].imshow(img_mask, alpha=.2, cmap='binary')  # PTV
dose = ax[0].imshow(img_dose, cmap='jet', alpha=.2)
plt.colorbar(dose, ax=ax[0])
ax[1].plot(target_DVH.histogram[0], target_DVH.histogram[1], label=target_DVH.name)
ax[1].set_xlabel("Dose (Gy)")
ax[1].set_ylabel("Volume (%)")
plt.grid(True)
plt.legend()

plt.show()
# Out:
# D95 = 15.10009765625 Gy
# D5 = 23.32763671875 Gy
# D5 - D95 =  8.2275390625 Gy
# 27/07/2023 05:27:40 PM - opentps.core.processing.imageProcessing.roiMasksProcessing - INFO - Using SITK to dilate mask.
